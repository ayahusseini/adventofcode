# %% [markdown]
# ## Noah's rug Day 2
#
# ### Imports

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ## Establishing a database connection

# %%
DATABASE = "noahs.sqlite"
conn = sqlite3.connect(DATABASE)

# %% [markdown]
# ## The task
#
# - claim ticket said '2017 JP'
# - Item brought in in the year 2017
# - Initials of the contracter are 'JP'

# %%
query = """
SELECT *
FROM customers AS c
INNER JOIN orders o ON c.customerid = o.customerid
LEFT OUTER JOIN orders_items oi on oi.orderid = o.orderid
LEFT JOIN products p on p.sku = oi.sku
WHERE strftime("%Y",o.ordered) == '2017'
AND c.name LIKE 'J% P%'
AND p.desc LIKE '%Cleaner%'
;
"""

# %%
pd.read_sql(query,conn)
# Out:
#    customerid             name          address       citystatezip  \
# 0        1475  Joshua Peterson  100-75 148th St  Jamaica, NY 11435
# 1        1475  Joshua Peterson  100-75 148th St  Jamaica, NY 11435
# 2        1475  Joshua Peterson  100-75 148th St  Jamaica, NY 11435
# 3        1475  Joshua Peterson  100-75 148th St  Jamaica, NY 11435
# 4        1475  Joshua Peterson  100-75 148th St  Jamaica, NY 11435
#
#     birthdate         phone          timezone       lat      long orderid  \
# 0  1947-02-05  332-274-4185  America/New_York  40.70895 -73.80856    7459
# 1  1947-02-05  332-274-4185  America/New_York  40.70895 -73.80856    7783
# 2  1947-02-05  332-274-4185  America/New_York  40.70895 -73.80856    8051
# 3  1947-02-05  332-274-4185  America/New_York  40.70895 -73.80856    8375
# 4  1947-02-05  332-274-4185  America/New_York  40.70895 -73.80856    8663
#
#    ... total items orderid      sku qty  unit_price      sku         desc  \
# ...
